# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
# %matplotlib inline

# %%
r = requests.get('https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita')
gdptable = r.text
soup = BeautifulSoup(gdptable, 'lxml')
table = soup.find('table', attrs = {"class" :"wikitable sortable"})


theads=[]
for tx in table.findAll('th'):
    theads.append(tx.text)

data =[]
for rows in table.findAll('tr'):
        row={}
        i=0
        for cell in rows.findAll('td'):
            row[theads[i]]=re.sub('\xa0', '',cell.text)
            i+=1
        if len(row)!=0:
            data.append(row)

print(data)

#http://arijitgeek.me/index.php/2016/11/18/wiki-table-python-script-to-fetch-tables-from-wikipedia-to-pandas-dataframe/
# Out:
# [{'US$': '103,199', 'Rank': '1', 'Country': 'Luxembourg'}, {'US$': '79,242', 'Rank': '2', 'Country': 'Switzerland'}, {'US$': '70,392', 'Rank': '3', 'Country': 'Norway'}, {'US$': '67,079', 'Rank': '—', 'Country': 'Macau'}, {'US$': '62,562', 'Rank': '4', 'Country': 'Ireland'}, {'US$': '60,787', 'Rank': '5', 'Country': 'Qatar'}, {'US$': '59,629', 'Rank': '6', 'Country': 'Iceland'}, {'US$': '57,436', 'Rank': '7', 'Country': 'United States'}, {'US$': '53,744', 'Rank': '8', 'Country': 'Denmark'}, {'US$': '52,961', 'Rank': '9', 'Country': 'Singapore'}, {'US$': '51,850', 'Rank': '10', 'Country': 'Australia'}, {'US$': '51,165', 'Rank': '11', 'Country': 'Sweden'}, {'US$': '46,447', 'Rank': '12', 'Country': 'San Marino'}, {'US$': '45,283', 'Rank': '13', 'Country': 'Netherlands'}, {'US$': '44,498', 'Rank': '14', 'Country': 'Austria'}, {'US$': '43,528', 'Rank': '—', 'Country': 'Hong Kong'}, {'US$': '43,169', 'Rank': '15', 'Country': 'Finland'}, {'US$': '42,210', 'Rank': '16', 'Country': 'Canada'}, {'US$': '41,902', 'Rank': '17', 'Country': 'Germany'}, {'US$': '41,283', 'Rank': '18', 'Country': 'Belgium'}, {'US$': '40,096', 'Rank': '19', 'Country': 'United Kingdom'}, {'US$': '38,917', 'Rank': '20', 'Country': 'Japan'}, {'US$': '38,345', 'Rank': '21', 'Country': 'New Zealand'}, {'US$': '38,128', 'Rank': '22', 'Country': 'France'}, {'US$': '37,678', 'Rank': '23', 'Country': 'United Arab Emirates'}, {'US$': '37,262', 'Rank': '24', 'Country': 'Israel'}, {'US$': '30,507', 'Rank': '25', 'Country': 'Italy'}, {'US$': '29,697', 'Rank': '—', 'Country': 'Puerto Rico'}, {'US$': '27,539', 'Rank': '26', 'Country': 'South Korea'}, {'US$': '26,609', 'Rank': '27', 'Country': 'Spain'}, {'US$': '26,424', 'Rank': '28', 'Country': 'Brunei'}, {'US$': '26,005', 'Rank': '29', 'Country': 'Kuwait'}, {'US$': '25,214', 'Rank': '30', 'Country': 'Malta'}, {'US$': '24,272', 'Rank': '31', 'Country': 'Bahamas, The'}, {'US$': '24,183', 'Rank': '32', 'Country': 'Bahrain'}, {'US$': '23,352', 'Rank': '33', 'Country': 'Cyprus'}, {'US$': '22,453', 'Rank': '—', 'Country': 'Taiwan'}, {'US$': '21,320', 'Rank': '34', 'Country': 'Slovenia'}, {'US$': '20,150', 'Rank': '35', 'Country': 'Saudi Arabia'}, {'US$': '19,832', 'Rank': '36', 'Country': 'Portugal'}, {'US$': '18,286', 'Rank': '37', 'Country': 'Czech Republic'}, {'US$': '17,901', 'Rank': '38', 'Country': 'Greece'}, {'US$': '17,633', 'Rank': '39', 'Country': 'Estonia'}, {'US$': '16,499', 'Rank': '40', 'Country': 'Slovakia'}, {'US$': '16,363', 'Rank': '41', 'Country': 'Barbados'}, {'US$': '16,222', 'Rank': '42', 'Country': 'Palau'}, {'US$': '16,058', 'Rank': '43', 'Country': 'Saint Kitts and Nevis'}, {'US$': '15,964', 'Rank': '44', 'Country': 'Oman'}, {'US$': '15,679', 'Rank': '45', 'Country': 'Uruguay'}, {'US$': '15,488', 'Rank': '46', 'Country': 'Antigua and Barbuda'}, {'US$': '15,342', 'Rank': '47', 'Country': 'Trinidad and Tobago'}, {'US$': '14,938', 'Rank': '48', 'Country': 'Seychelles'}, {'US$': '14,890', 'Rank': '49', 'Country': 'Lithuania'}, {'US$': '14,174', 'Rank': '50', 'Country': 'Equatorial Guinea'}, {'US$': '14,060', 'Rank': '51', 'Country': 'Latvia'}, {'US$': '13,654', 'Rank': '52', 'Country': 'Panama'}, {'US$': '13,576', 'Rank': '53', 'Country': 'Chile'}, {'US$': '12,778', 'Rank': '54', 'Country': 'Hungary'}, {'US$': '12,503', 'Rank': '55', 'Country': 'Argentina'}, {'US$': '12,316', 'Rank': '56', 'Country': 'Poland'}, {'US$': '12,095', 'Rank': '57', 'Country': 'Croatia'}, {'US$': '11,835', 'Rank': '58', 'Country': 'Costa Rica'}, {'US$': '11,309', 'Rank': '59', 'Country': 'Lebanon'}, {'US$': '10,743', 'Rank': '60', 'Country': 'Turkey'}, {'US$': '10,038', 'Rank': '—', 'Country': 'World'}, {'US$': '9,585', 'Rank': '61', 'Country': 'Grenada'}, {'US$': '9,554', 'Rank': '62', 'Country': 'Maldives'}, {'US$': '9,465', 'Rank': '63', 'Country': 'Romania'}, {'US$': '9,424', 'Rank': '64', 'Country': 'Mauritius'}, {'US$': '9,360', 'Rank': '65', 'Country': 'Malaysia'}, {'US$': '9,258', 'Rank': '66', 'Country': 'Venezuela'}, {'US$ ...

# %%
gdp = pd.DataFrame(data)

# %%
gdp.head()
# Out:
#        Country Rank      US$
# 0   Luxembourg    1  103,199
# 1  Switzerland    2   79,242
# 2       Norway    3   70,392
# 3        Macau    —   67,079
# 4      Ireland    4   62,562

# %%
gdp = gdp.rename(columns = {'US$':'gdp_per_capita'})

# %%
gdp.head()
# Out:
#        Country Rank gdp_per_capita
# 0   Luxembourg    1        103,199
# 1  Switzerland    2         79,242
# 2       Norway    3         70,392
# 3        Macau    —         67,079
# 4      Ireland    4         62,562

# %%
del gdp['Rank']

# %%
gdp.head()
# Out:
#        Country gdp_per_capita
# 0   Luxembourg        103,199
# 1  Switzerland         79,242
# 2       Norway         70,392
# 3        Macau         67,079
# 4      Ireland         62,562

# %%
gdp.gdp_per_capita.describe()
# Out:
# count       191
# unique      191
# top       3,685
# freq          1
# Name: gdp_per_capita, dtype: object

# %%
gdp['gdp_per_capita'] = gdp['gdp_per_capita'].apply(lambda x: re.sub(',','',x))

# %%
gdp.head()
# Out:
#        Country gdp_per_capita
# 0   Luxembourg         103199
# 1  Switzerland          79242
# 2       Norway          70392
# 3        Macau          67079
# 4      Ireland          62562

# %%
gdp['gdp_per_capita'] = gdp['gdp_per_capita'].apply(pd.to_numeric)

# %%
gdp.head()
# Out:
#        Country  gdp_per_capita
# 0   Luxembourg          103199
# 1  Switzerland           79242
# 2       Norway           70392
# 3        Macau           67079
# 4      Ireland           62562

# %%
gdp.gdp_per_capita.mean()
# Out:
# 13037.277486910994

# %%
gdp.gdp_per_capita.describe()
# Out:
# count       191.000000
# mean      13037.277487
# std       17754.516597
# min         233.000000
# 25%        1904.500000
# 50%        5193.000000
# 75%       15821.500000
# max      103199.000000
# Name: gdp_per_capita, dtype: float64

# %%
gdp50000 = gdp[gdp['gdp_per_capita'] > 50000]

# %%
gdp50000
# Out:
#           Country  gdp_per_capita
# 0      Luxembourg          103199
# 1     Switzerland           79242
# 2          Norway           70392
# 3           Macau           67079
# 4         Ireland           62562
# 5           Qatar           60787
# 6         Iceland           59629
# 7   United States           57436
# 8         Denmark           53744
# 9       Singapore           52961
# 10      Australia           51850
# 11         Sweden           51165

# %%
sgdp = gdp[gdp['Country'].str.startswith('S')]

# %%
sgdp
# Out:
#                               Country  gdp_per_capita
# 1                         Switzerland           79242
# 9                           Singapore           52961
# 11                             Sweden           51165
# 12                         San Marino           46447
# 28                        South Korea           27539
# 29                              Spain           26609
# 37                           Slovenia           21320
# 38                       Saudi Arabia           20150
# 43                           Slovakia           16499
# 46              Saint Kitts and Nevis           16058
# 51                         Seychelles           14938
# 75                        Saint Lucia            7940
# 82   Saint Vincent and the Grenadines            7038
# 86                           Suriname            6333
# 92                             Serbia            5376
# 94                       South Africa            5261
# 108                             Samoa            4035
# 112                         Sri Lanka            3887
# 122                         Swaziland            3330
# 133                             Sudan            2384
# 140                   Solomon Islands            1971
# 146             Sao Tome and Principe            1687
# 162                           Senegal             960
# 177                      Sierra Leone             618
# 190                       South Sudan             233

# %%
len(sgdp)
# Out:
# 25

# %%
sand500gdp = gdp[(gdp.gdp_per_capita > 50000) & (gdp.Country.str.startswith('S'))]

# %%
sand500gdp
# Out:
#         Country  gdp_per_capita
# 1   Switzerland           79242
# 9     Singapore           52961
# 11       Sweden           51165

# %%
sor500gdp = gdp[(gdp.gdp_per_capita > 50000) | (gdp.Country.str.startswith('S'))]

# %%
sor500gdp
# Out:
#                               Country  gdp_per_capita
# 0                          Luxembourg          103199
# 1                         Switzerland           79242
# 2                              Norway           70392
# 3                               Macau           67079
# 4                             Ireland           62562
# 5                               Qatar           60787
# 6                             Iceland           59629
# 7                       United States           57436
# 8                             Denmark           53744
# 9                           Singapore           52961
# 10                          Australia           51850
# 11                             Sweden           51165
# 12                         San Marino           46447
# 28                        South Korea           27539
# 29                              Spain           26609
# 37                           Slovenia           21320
# 38                       Saudi Arabia           20150
# 43                           Slovakia           16499
# 46              Saint Kitts and Nevis           16058
# 51                         Seychelles           14938
# 75                        Saint Lucia            7940
# 82   Saint Vincent and the Grenadines            7038
# 86                           Suriname            6333
# 92                             Serbia            5376
# 94                       South Africa            5261
# 108                             Samoa            4035
# 112                         Sri Lanka            3887
# 122                         Swaziland            3330
# 133                             Sudan            2384
# 140                   Solomon Islands            1971
# 146             Sao Tome and Principe            1687
# 162                           Senegal             960
# 177                      Sierra Leone             618
# 190                       South Sudan             233

# %%
gdp50000.gdp_per_capita.sum()
# Out:
# 770046

# %%
gdp50000.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x115721da0>]], dtype=object)

# %%
country = pd.read_csv("Country.csv")

# %%
country.head()
# Out:
#   CountryCode       ShortName       TableName  \
# 0         AFG     Afghanistan     Afghanistan
# 1         ALB         Albania         Albania
# 2         DZA         Algeria         Algeria
# 3         ASM  American Samoa  American Samoa
# 4         ADO         Andorra         Andorra
#
#                                   LongName Alpha2Code    CurrencyUnit  \
# 0             Islamic State of Afghanistan         AF  Afghan afghani
# 1                      Republic of Albania         AL    Albanian lek
# 2  People's Democratic Republic of Algeria         DZ  Algerian dinar
# 3                           American Samoa         AS     U.S. dollar
# 4                  Principality of Andorra         AD            Euro
#
#                                         SpecialNotes  \
# 0  Fiscal year end: March 20; reporting period fo...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                        Region           IncomeGroup Wb2Code  \
# 0                  South Asia            Low income      AF
# 1       Europe & Central Asia   Upper middle income      AL
# 2  Middle East & North Africa   Upper middle income      DZ
# 3         East Asia & Pacific   Upper middle income      AS
# 4       Europe & Central Asia  High income: nonOECD      AD
#
#              ...                 GovernmentAccountingConcept  \
# 0            ...             Consolidated central government
# 1            ...                Budgetary central government
# 2            ...                Budgetary central government
# 3            ...                                         NaN
# 4            ...                                         NaN
#
#                ImfDataDisseminationStandard  \
# 0  General Data Dissemination System (GDDS)
# 1  General Data Dissemination System (GDDS)
# 2  General Data Dissemination System (GDDS)
# 3                                       NaN
# 4                                       NaN
#
#                               LatestPopulationCensus  \
# 0                                               1979
# 1                                               2011
# 2                                               2008
# 3                                               2010
# 4  2011. Population data compiled from administra...
#
#                                LatestHouseholdSurvey  \
# 0  Multiple Indicator Cluster Survey (MICS), 2010/11
# 1       Demographic and Health Survey (DHS), 2008/09
# 2     Multiple Indicator Cluster Survey (MICS), 2012
# 3                                                NaN
# 4                                                NaN
#
#           SourceOfMostRecentIncomeAndExpenditureData  \
# 0            Integrated household survey (IHS), 2008
# 1  Living Standards Measurement Study Survey (LSM...
# 2            Integrated household survey (IHS), 1995
# 3                                                NaN
# 4                                                NaN
#
#   VitalRegistrationComplete LatestAgriculturalCensus LatestIndustrialData  \
# 0                       NaN                  2013/14                  NaN
# 1                       Yes                     2012               2011.0
# 2                       NaN                      NaN               2010.0
# 3                       Yes                     2007                  NaN
# 4                       Yes                      NaN                  NaN
#
#   LatestTradeData LatestWaterWithdrawalData
# 0          2013.0                    2000.0
# 1          2013.0                    2006.0
# 2          2013.0                    2001.0
# 3             NaN                       NaN
# 4          2006.0                       NaN
#
# [5 rows x 31 columns]

# %%
gdpfinal = pd.merge(gdp,country, how = 'inner', left_on='Country', right_on = 'TableName')

# %%
gdpfinal
# Out:
#                       Country  gdp_per_capita CountryCode  \
# 0                  Luxembourg          103199         LUX
# 1                 Switzerland           79242         CHE
# 2                      Norway           70392         NOR
# 3                     Ireland           62562         IRL
# 4                       Qatar           60787         QAT
# 5                     Iceland           59629         ISL
# 6               United States           57436         USA
# 7                     Denmark           53744         DNK
# 8                   Singapore           52961         SGP
# 9                   Australia           51850         AUS
# 10                     Sweden           51165         SWE
# 11                 San Marino           46447         SMR
# 12                Netherlands           45283         NLD
# 13                    Austria           44498         AUT
# 14                    Finland           43169         FIN
# 15                     Canada           42210         CAN
# 16                    Germany           41902         DEU
# 17                    Belgium           41283         BEL
# 18             United Kingdom           40096         GBR
# 19                      Japan           38917         JPN
# 20                New Zealand           38345         NZL
# 21                     France           38128         FRA
# 22       United Arab Emirates           37678         ARE
# 23                     Israel           37262         ISR
# 24                      Italy           30507         ITA
# 25                Puerto Rico           29697         PRI
# 26                      Spain           26609         ESP
# 27                     Kuwait           26005         KWT
# 28                      Malta           25214         MLT
# 29               Bahamas, The           24272         BHS
# ..                        ...             ...         ...
# 137                   Lesotho            1170         LSO
# 138                  Zimbabwe             977         ZWE
# 139                  Tanzania             970         TZA
# 140                   Senegal             960         SEN
# 141                      Chad             852         TCD
# 142                      Mali             830         MLI
# 143                   Eritrea             823         ERI
# 144                Tajikistan             800         TJK
# 145                  Ethiopia             795         ETH
# 146                     Benin             771         BEN
# 147                     Haiti             761         HTI
# 148                   Comoros             753         COM
# 149                     Nepal             733         NPL
# 150                    Rwanda             729         RWA
# 151             Guinea-Bissau             694         GNB
# 152              Burkina Faso             646         BFA
# 153                    Uganda             638         UGA
# 154              Sierra Leone             618         SLE
# 155                      Togo             590         TGO
# 156               Afghanistan             565         AFG
# 157                    Guinea             515         GIN
# 158                   Liberia             480         LBR
# 159               Gambia, The             469         GMB
# 160                     Niger             411         NER
# 161                Mozambique             392         MOZ
# 162                Madagascar             391         MDG
# 163  Central African Republic             364         CAF
# 164                   Burundi             325         BDI
# 165                    Malawi             295         MWI
# 166               South Sudan             233         SSD
#
#                     ShortName                 TableName  \
# 0                  Luxembourg                Luxembourg
# 1                 Switzerland               Switzerland
# 2                      Norway                    Norway
# 3                     Ireland                   Ireland
# 4                       Qatar                     Qatar
# 5                     Iceland                   Iceland
# 6               United States             United States
# 7                     Denmark                   Denmark
# 8                   Singapore                 Singapore
# 9                   Australia                 Australia
# 10                     Sweden                    Sweden
# 11                 San Marino                San Marino
# 12                Netherlands               Netherlands
# 13                    Austria                   Austria
# 14                    Finland                   Finland
# 15                     Canada                    Canada
# 16                    Germany                   Germany
# 17                    Belgium                   Belgium
# 18             United Kingdom            United Kingdom
# 19                      Japan                     Japan
# 20                New Zealand               New Zealand
# 21                     France                    France
# 22       United Arab Emirates      United Arab Emirates
# 23                     Israel                    Israel
# 24                      Italy                     Italy
# 25                Puerto Rico               Puerto Rico
# 26                      Spain                     Spain
# 27                     Kuwait                    Kuwait
# 28                      Malta                     Malta
# 29                The Bahamas              Bahamas, The
# ..                        ...                       ...
# 137                   Lesotho                   Lesotho
# 138                  Zimbabwe                  Zimbabwe
# 139                  Tanzania                  Tanzania
# 140                   Senegal                   Senegal
# 141                      Chad                      Chad
# 142                      Mali                      Mali
# 143                   Eritrea                   Eritrea
# 144                Tajikistan                Tajikistan
# 145                  Ethiopia                  Ethiopia
# 146                     Benin                     Benin
# 147                     Haiti                     Haiti
# 148                   Comoros                   Comoros
# 149                     Nepal                     Nepal
# 150                    Rwanda                    Rwanda
# 151             Guinea-Bissau             Guinea-Bissau
# 152              Burkina Faso              Burkina Faso
# 153                    Uganda                    Uganda
# 154              Sierra Leone              Sierra Leone
# 155                      Togo                      Togo
# 156               Afghanistan               Afghanistan
# 157                    Guinea                    Guinea
# 158                   Liberia                   Liberia
# 159                The Gambia               Gambia, The
# 160                     Niger                     Niger
# 161                Mozambique                Mozambique
# 162                Madagascar                Madagascar
# 163  Central African Republic  Central African Republic
# 164                   Burundi                   Burundi
# 165                    Malawi                    Malawi
# 166               South Sudan               South Sudan
#
#                                               LongName Alpha2Code  \
# 0                            Grand Duchy of Luxembourg         LU
# 1                                          Switzerland         CH
# 2                                    Kingdom of Norway         NO
# 3                                              Ireland         IE
# 4                                       State of Qatar         QA
# 5                                  Republic of Iceland         IS
# 6                             United States of America         US
# 7                                   Kingdom of Denmark         DK
# 8                                Republic of Singapore         SG
# 9                            Commonwealth of Australia         AU
# 10                                   Kingdom of Sweden         SE
# 11                              Republic of San Marino         SM
# 12                          Kingdom of the Netherlands         NL
# 13                                 Republic of Austria         AT
# 14                                 Republic of Finland         FI
# 15                                              Canada         CA
# 16                         Federal Republic of Germany         DE
# 17                                  Kingdom of Belgium         BE
# 18   United Kingdom of Great Britain and Northern I...         GB
# 19                                               Japan         JP
# 20                                         New Zealand         NZ
# 21                                     French Republic         FR
# 22                                United Arab Emirates         AE
# 23                                     State of Israel         IL
# 24                                    Italian Republic         IT
# 25                                         Puerto Rico         PR
# 26                                    Kingdom of Spain         ES
# 27                                     State of Kuwait         KW
# 28                                   Republic of Malta         MT
# 29                         Commonwealth of The Bahamas         BS
# ..                                                 ...        ...
# 137                                 Kingdom of Lesotho         LS
# 138                               Republic of Zimbabwe         ZW
# 139                        United Republic of Tanzania         TZ
# 140                                Republic of Senegal         SN
# 141                                   Republic of Chad         TD
# 142                                   Republic of Mali         ML
# 143                                   State of Eritrea         ER
# 144                             Republic of Tajikistan         TJ
# 145            Federal Democratic Republic of Ethiopia         ET
# 146                                  Republic of Benin         BJ
# 147                                  Republic of Haiti         HT
# 148                               Union of the Comoros         KM
# 149                                              Nepal         NP
# 150                                 Republic of Rwanda         RW
# 151                          Republic of Guinea-Bissau         GW
# 152                                       Burkina Faso         BF
# 153                                 Republic of Uganda         UG
# 154                           Republic of Sierra Leone         SL
# 155                                   Republic of Togo         TG
# 156                       Islamic State of Afghanistan         AF
# 157                                 Republic of Guinea         GN
# 158                                Republic of Liberia         LR
# 159                             Republic of The Gambia         GM
# 160                                  Republic of Niger         NE
# 161                             Republic of Mozambique         MZ
# 162                             Republic of Madagascar         MG
# 163                           Central African Republic         CF
# 164                                Republic of Burundi         BI
# 165                                 Republic of Malawi         MW
# 166                            Republic of South Sudan         SS
#
#                   CurrencyUnit  \
# 0                         Euro
# 1                  Swiss franc
# 2              Norwegian krone
# 3                         Euro
# 4                 Qatari riyal
# 5                Iceland krona
# 6                  U.S. dollar
# 7                 Danish krone
# 8             Singapore dollar
# 9            Australian dollar
# 10               Swedish krona
# 11                        Euro
# 12                        Euro
# 13                        Euro
# 14                        Euro
# 15             Canadian dollar
# 16                        Euro
# 17                        Euro
# 18              Pound sterling
# 19                Japanese yen
# 20          New Zealand dollar
# 21                        Euro
# 22               U.A.E. dirham
# 23          Israeli new shekel
# 24                        Euro
# 25                 U.S. dollar
# 26                        Euro
# 27               Kuwaiti dinar
# 28                        Euro
# 29             Bahamian dollar
# ..                         ...
# 137               Lesotho loti
# 138                U.S. dollar
# 139         Tanzanian shilling
# 140     West African CFA franc
# 141  Central African CFA franc
# 142     West African CFA franc
# 143             Eritrean nakfa
# 144               Tajik somoni
# 145             Ethiopian birr
# 146     West African CFA franc
# 147             Haitian gourde
# 148             Comorian franc
# 149             Nepalese rupee
# 150              Rwandan franc
# 151     West African CFA franc
# 152     West African CFA franc
# 153           Ugandan shilling
# 154       Sierra Leonean leone
# 155     West African CFA franc
# 156             Afghan afghani
# 157              Guinean franc
# 158                U.S. dollar
# 159             Gambian dalasi
# 160     West African CFA franc
# 161     New Mozambican metical
# 162            Malagasy ariary
# 163  Central African CFA franc
# 164              Burundi franc
# 165              Malawi kwacha
# 166       South Sudanese Pound
#
#                                           SpecialNotes  \
# 0    A simple multiplier is used to convert the nat...
# 1                                                  NaN
# 2                                                  NaN
# 3    A simple multiplier is used to convert the nat...
# 4                                                  NaN
# 5                                                  NaN
# 6    Fiscal year end: September 30; reporting perio...
# 7                                                  NaN
# 8    Fiscal year end: March 31; reporting period fo...
# 9    Fiscal year end: June 30; reporting period for...
# 10   Fiscal year end: June 30; reporting period for...
# 11                                                 NaN
# 12   A simple multiplier is used to convert the nat...
# 13   A simple multiplier is used to convert the nat...
# 14   A simple multiplier is used to convert the nat...
# 15   Fiscal year end: March 31; reporting period fo...
# 16   A simple multiplier is used to convert the nat...
# 17   A simple multiplier is used to convert the nat...
# 18                                                 NaN
# 19   Fiscal year end: March 31; reporting period fo...
# 20   Fiscal year end: March 31; reporting period fo...
# 21   A simple multiplier is used to convert the nat...
# 22   April 2013 database update: Based on data from...
# 23   Based on official government statistics for ch...
# 24   A simple multiplier is used to convert the nat...
# 25   Fiscal year end: June 30; reporting period for...
# 26   A simple multiplier is used to convert the nat...
# 27   Fiscal year end: June 30; reporting period for...
# 28   A simple multiplier is used to convert the nat...
# 29                                                 NaN
# ..                                                 ...
# 137  Fiscal year end: March 31; reporting period fo...
# 138  Fiscal year end: June 30; reporting period for...
# 139  The new base year is 2007. Tanzania reports us...
# 140                                                NaN
# 141  Based on IMF data, national accounts data have...
# 142                                                NaN
# 143  April 2013 database update: Based on IMF data,...
# 144                                                NaN
# 145  Fiscal year end: July 7; reporting period for ...
# 146                                                NaN
# 147  Fiscal year end: September 30; reporting perio...
# 148                                                NaN
# 149  Fiscal year end: July 14; reporting period for...
# 150  Based on official government statistics, natio...
# 151  In 2010, national accounts data for 2003-09 we...
# 152                                                NaN
# 153  Fiscal year end: June 30; reporting period for...
# 154  Fiscal year end: June 30; reporting period for...
# 155  April 2013 database update: Based on IMF data,...
# 156  Fiscal year end: March 20; reporting period fo...
# 157                                                NaN
# 158  National accounts local currency data have bee...
# 159  Fiscal year end: June 30; reporting period for...
# 160  Based on official government statistics, natio...
# 161  Based on official government statistics; the n...
# 162                                                NaN
# 163                                                NaN
# 164                                                NaN
# 165  Fiscal year end: March 31; reporting period fo...
# 166  South Sudan declared its independence on July ...
#
#                          Region            ...             \
# 0         Europe & Central Asia            ...
# 1         Europe & Central Asia            ...
# 2         Europe & Central Asia            ...
# 3         Europe & Central Asia            ...
# 4    Middle East & North Africa            ...
# 5         Europe & Central Asia            ...
# 6                 North America            ...
# 7         Europe & Central Asia            ...
# 8           East Asia & Pacific            ...
# 9           East Asia & Pacific            ...
# 10        Europe & Central Asia            ...
# 11        Europe & Central Asia            ...
# 12        Europe & Central Asia            ...
# 13        Europe & Central Asia            ...
# 14        Europe & Central Asia            ...
# 15                North America            ...
# 16        Europe & Central Asia            ...
# 17        Europe & Central Asia            ...
# 18        Europe & Central Asia            ...
# 19          East Asia & Pacific            ...
# 20          East Asia & Pacific            ...
# 21        Europe & Central Asia            ...
# 22   Middle East & North Africa            ...
# 23   Middle East & North Africa            ...
# 24        Europe & Central Asia            ...
# 25    Latin America & Caribbean            ...
# 26        Europe & Central Asia            ...
# 27   Middle East & North Africa            ...
# 28   Middle East & North Africa            ...
# 29    Latin America & Caribbean            ...
# ..                          ...            ...
# 137          Sub-Saharan Africa            ...
# 138          Sub-Saharan Africa            ...
# 139          Sub-Saharan Africa            ...
# 140          Sub-Saharan Africa            ...
# 141          Sub-Saharan Africa            ...
# 142          Sub-Saharan Africa            ...
# 143          Sub-Saharan Africa            ...
# 144       Europe & Central Asia            ...
# 145          Sub-Saharan Africa            ...
# 146          Sub-Saharan Africa            ...
# 147   Latin America & Caribbean            ...
# 148          Sub-Saharan Africa            ...
# 149                  South Asia            ...
# 150          Sub-Saharan Africa            ...
# 151          Sub-Saharan Africa            ...
# 152          Sub-Saharan Africa            ...
# 153          Sub-Saharan Africa            ...
# 154          Sub-Saharan Africa            ...
# 155          Sub-Saharan Africa            ...
# 156                  South Asia            ...
# 157          Sub-Saharan Africa            ...
# 158          Sub-Saharan Africa            ...
# 159          Sub-Saharan Africa            ...
# 160          Sub-Saharan Africa            ...
# 161          Sub-Saharan Africa            ...
# 162          Sub-Saharan Africa            ...
# 163          Sub-Saharan Africa            ...
# 164          Sub-Saharan Africa            ...
# 165          Sub-Saharan Africa            ...
# 166          Sub-Saharan Africa            ...
#
#          GovernmentAccountingConcept  \
# 0    Consolidated central government
# 1    Consolidated central government
# 2    Consolidated central government
# 3    Consolidated central government
# 4       Budgetary central government
# 5    Consolidated central government
# 6    Consolidated central government
# 7    Consolidated central government
# 8    Consolidated central government
# 9    Consolidated central government
# 10   Consolidated central government
# 11   Consolidated central government
# 12   Consolidated central government
# 13   Consolidated central government
# 14   Consolidated central government
# 15   Consolidated central government
# 16   Consolidated central government
# 17   Consolidated central government
# 18   Consolidated central government
# 19   Consolidated central government
# 20   Consolidated central government
# 21   Consolidated central government
# 22   Consolidated central government
# 23   Consolidated central government
# 24   Consolidated central government
# 25                               NaN
# 26   Consolidated central government
# 27      Budgetary central government
# 28   Consolidated central government
# 29      Budgetary central government
# ..                               ...
# 137  Consolidated central government
# 138  Consolidated central government
# 139     Budgetary central government
# 140     Budgetary central government
# 141                              NaN
# 142     Budgetary central government
# 143                              NaN
# 144  Consolidated central government
# 145     Budgetary central government
# 146     Budgetary central government
# 147                              NaN
# 148                              NaN
# 149     Budgetary central government
# 150     Budgetary central government
# 151                              NaN
# 152     Budgetary central government
# 153     Budgetary central government
# 154     Budgetary central government
# 155     Budgetary central government
# 156  Consolidated central government
# 157     Budgetary central government
# 158     Budgetary central government
# 159     Budgetary central government
# 160     Budgetary central government
# 161     Budgetary central government
# 162  Consolidated central government
# 163     Budgetary central government
# 164  Consolidated central government
# 165                              NaN
# 166                              NaN
#
#                    ImfDataDisseminationStandard  \
# 0    Special Data Dissemination Standard (SDDS)
# 1    Special Data Dissemination Standard (SDDS)
# 2    Special Data Dissemination Standard (SDDS)
# 3    Special Data Dissemination Standard (SDDS)
# 4      General Data Dissemination System (GDDS)
# 5    Special Data Dissemination Standard (SDDS)
# 6    Special Data Dissemination Standard (SDDS)
# 7    Special Data Dissemination Standard (SDDS)
# 8    Special Data Dissemination Standard (SDDS)
# 9    Special Data Dissemination Standard (SDDS)
# 10   Special Data Dissemination Standard (SDDS)
# 11     General Data Dissemination System (GDDS)
# 12   Special Data Dissemination Standard (SDDS)
# 13   Special Data Dissemination Standard (SDDS)
# 14   Special Data Dissemination Standard (SDDS)
# 15   Special Data Dissemination Standard (SDDS)
# 16   Special Data Dissemination Standard (SDDS)
# 17   Special Data Dissemination Standard (SDDS)
# 18   Special Data Dissemination Standard (SDDS)
# 19   Special Data Dissemination Standard (SDDS)
# 20                                          NaN
# 21   Special Data Dissemination Standard (SDDS)
# 22     General Data Dissemination System (GDDS)
# 23   Special Data Dissemination Standard (SDDS)
# 24   Special Data Dissemination Standard (SDDS)
# 25                                          NaN
# 26   Special Data Dissemination Standard (SDDS)
# 27     General Data Dissemination System (GDDS)
# 28   Special Data Dissemination Standard (SDDS)
# 29     General Data Dissemination System (GDDS)
# ..                                          ...
# 137    General Data Dissemination System (GDDS)
# 138    General Data Dissemination System (GDDS)
# 139    General Data Dissemination System (GDDS)
# 140    General Data Dissemination System (GDDS)
# 141    General Data Dissemination System (GDDS)
# 142    General Data Dissemination System (GDDS)
# 143                                         NaN
# 144    General Data Dissemination System (GDDS)
# 145    General Data Dissemination System (GDDS)
# 146    General Data Dissemination System (GDDS)
# 147    General Data Dissemination System (GDDS)
# 148    General Data Dissemination System (GDDS)
# 149    General Data Dissemination System (GDDS)
# 150    General Data Dissemination System (GDDS)
# 151    General Data Dissemination System (GDDS)
# 152    General Data Dissemination System (GDDS)
# 153    General Data Dissemination System (GDDS)
# 154    General Data Dissemination System (GDDS)
# 155    General Data Dissemination System (GDDS)
# 156    General Data Dissemination System (GDDS)
# 157    General Data Dissemination System (GDDS)
# 158    General Data Dissemination System (GDDS)
# 159    General Data Dissemination System (GDDS)
# 160    General Data Dissemination System (GDDS)
# 161    General Data Dissemination System (GDDS)
# 162    General Data Dissemination System (GDDS)
# 163    General Data Dissemination System (GDDS)
# 164    General Data Dissemination System (GDDS)
# 165    General Data Dissemination System (GDDS)
# 166                                         NaN
#
#                                 LatestPopulationCensus  \
# 0                                                 2011
# 1                                                 2010
# 2                                                 2011
# 3                                                 2011
# 4                                                 2010
# 5                                                 2011
# 6                                                 2010
# 7                                                 2011
# 8                                                 2010
# 9                                                 2011
# 10                                                2011
# 11                                                2010
# 12                                                2011
# 13   2011. Population data compiled from administra...
# 14                                                2010
# 15                                                2011
# 16                                                2011
# 17                                                2011
# 18                                                2011
# 19                                                2010
# 20                                                2013
# 21   2006. Rolling census based on continuous sampl...
# 22                                                2010
# 23                                                2009
# 24                                                2012
# 25                                                2010
# 26                                                2011
# 27                                                2011
# 28                                                2011
# 29                                                2010
# ..                                                 ...
# 137                                               2006
# 138                                               2012
# 139                                               2012
# 140                                               2013
# 141                                               2009
# 142                                               2009
# 143                                               1984
# 144                                               2010
# 145                                               2007
# 146                                               2013
# 147                                               2003
# 148                                               2003
# 149                                               2011
# 150                                               2012
# 151                                               2009
# 152                                               2006
# 153                                               2014
# 154                                               2004
# 155                                               2010
# 156                                               1979
# 157                                               2014
# 158                                               2008
# 159                                               2013
# 160                                               2012
# 161                                               2007
# 162                                               1993
# 163                                               2003
# 164                                               2008
# 165                                               2008
# 166                                               2008
#
#                                  LatestHouseholdSurvey  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4       Multiple Indicator Cluster Survey (MICS), 2012
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                   National Health Survey (NHS), 2010
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                     World Health Survey (WHS), 2003
# 23                                                 NaN
# 24                                                 NaN
# 25           Reproductive Health Survey (RHS), 1995/96
# 26                                                 NaN
# 27                    Family Health Survey (FHS), 1996
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 137          Demographic and Health Survey (DHS), 2014
# 138     Multiple Indicator Cluster Survey (MICS), 2014
# 139  HIV/Maternal and Child Health (HIV/MCH) Servic...
# 140  HIV/Maternal and Child Health (HIV/MCH) Servic...
# 141          Demographic and Health Survey (DHS), 2014
# 142       Demographic and Health Survey (DHS), 2012/13
# 143          Demographic and Health Survey (DHS), 2002
# 144          Demographic and Health Survey (DHS), 2012
# 145  HIV/Maternal and Child Health (HIV/MCH) Servic...
# 146     Multiple Indicator Cluster Survey (MICS), 2014
# 147  HIV/Maternal and Child Health (HIV/MCH) Servic...
# 148          Demographic and Health Survey (DHS), 2012
# 149     Multiple Indicator Cluster Survey (MICS), 2014
# 150               Malaria Indicator Survey (MIS), 2013
# 151     Multiple Indicator Cluster Survey (MICS), 2014
# 152               Malaria Indicator Survey (MIS), 2014
# 153               Malaria Indicator Survey (MIS), 2014
# 154  Demographic and Health Survey (DHS), 2013; Mal...
# 155       Demographic and Health Survey (DHS), 2013/14
# 156  Multiple Indicator Cluster Survey (MICS), 2010/11
# 157          Demographic and Health Survey (DHS), 2012
# 158          Demographic and Health Survey (DHS), 2013
# 159          Demographic and Health Survey (DHS), 2013
# 160          Demographic and Health Survey (DHS), 2012
# 161          Demographic and Health Survey (DHS), 2011
# 162               Malaria Indicator Survey (MIS), 2013
# 163     Multiple Indicator Cluster Survey (MICS), 2010
# 164               Malaria Indicator Survey (MIS), 2012
# 165               Malaria Indicator Survey (MIS), 2014
# 166     Multiple Indicator Cluster Survey (MICS), 2010
#
#             SourceOfMostRecentIncomeAndExpenditureData  \
# 0                                                  NaN
# 1       Expenditure survey/budget survey (ES/BS), 2004
# 2                             Income survey (IS), 2010
# 3              Integrated household survey (IHS), 2010
# 4                                                  NaN
# 5              Integrated household survey (IHS), 2010
# 6                       Labor force survey (LFS), 2010
# 7                     Income tax registers (ITR), 2010
# 8                                                  NaN
# 9       Expenditure survey/budget survey (ES/BS), 2003
# 10                            Income survey (IS), 2005
# 11                                                 NaN
# 12             Integrated household survey (IHS), 2010
# 13             Integrated household survey (IHS), 2004
# 14             Integrated household survey (IHS), 2010
# 15                      Labor force survey (LFS), 2010
# 16             Integrated household survey (IHS), 2010
# 17             Integrated household survey (IHS), 2000
# 18                            Income survey (IS), 2010
# 19             Integrated household survey (IHS), 2008
# 20                                                 NaN
# 21      Expenditure survey/budget survey (ES/BS), 2005
# 22                                                 NaN
# 23      Expenditure survey/budget survey (ES/BS), 2010
# 24                            Income survey (IS), 2010
# 25                                                 NaN
# 26             Integrated household survey (IHS), 2010
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 137     Expenditure survey/budget survey (ES/BS), 2010
# 138         Integrated household survey (IHS), 2011/12
# 139  Expenditure survey/budget survey (ES/BS), 2011/12
# 140                         Priority survey (PS), 2011
# 141                         Priority survey (PS), 2011
# 142         Integrated household survey (IHS), 2009/10
# 143                         Priority survey (PS), 1993
# 144  Living Standards Measurement Study Survey (LSM...
# 145  Expenditure survey/budget survey (ES/BS), 2010/11
# 146  Core Welfare Indicator Questionnaire Survey (C...
# 147            Integrated household survey (IHS), 2012
# 148            Integrated household survey (IHS), 2004
# 149  Living Standards Measurement Study Survey (LSM...
# 150         Integrated household survey (IHS), 2010/11
# 151  Core Welfare Indicator Questionnaire Survey (C...
# 152  Core Welfare Indicator Questionnaire Survey (C...
# 153         Integrated household survey (IHS), 2012/13
# 154            Integrated household survey (IHS), 2011
# 155  Core Welfare Indicator Questionnaire Survey (C...
# 156            Integrated household survey (IHS), 2008
# 157  Core Welfare Indicator Questionnaire Survey (C...
# 158  Core Welfare Indicator Questionnaire Survey (C...
# 159            Integrated household survey (IHS), 2010
# 160  Core Welfare Indicator Questionnaire Survey (C...
# 161  Expenditure survey/budget survey (ES/BS), 2008/09
# 162                         Priority survey (PS), 2010
# 163                         Priority survey (PS), 2008
# 164  Core Welfare Indicator Questionnaire Survey (C...
# 165         Integrated household survey (IHS), 2010/11
# 166     Expenditure survey/budget survey (ES/BS), 2009
#
#     VitalRegistrationComplete              LatestAgriculturalCensus  \
# 0                         Yes                                  2010
# 1                         Yes                                  2008
# 2                         Yes                                  2010
# 3                         Yes                                  2010
# 4                         Yes                                   NaN
# 5                         Yes                                  2010
# 6                         Yes                                  2012
# 7                         Yes                                  2010
# 8                         Yes                                   NaN
# 9                         Yes                                  2011
# 10                        Yes                                  2010
# 11                        Yes                                   NaN
# 12                        Yes                                  2010
# 13                        Yes                                  2010
# 14                        Yes                                  2010
# 15                        Yes                                  2011
# 16                        Yes                                  2010
# 17                        Yes                                  2010
# 18                        Yes                                  2010
# 19                        Yes                                  2010
# 20                        Yes                                  2012
# 21                        Yes                                  2010
# 22                        NaN                                  2012
# 23                        Yes                                   NaN
# 24                        Yes                                  2010
# 25                        Yes                                  2007
# 26                        Yes                                  2010
# 27                        Yes                                   NaN
# 28                        Yes                                  2010
# 29                        NaN                                   NaN
# ..                        ...                                   ...
# 137                       NaN                                  2010
# 138                       NaN                                   NaN
# 139                       NaN                               2007/08
# 140                       NaN                                  2013
# 141                       NaN                            2010/ 2011
# 142                       NaN                                   NaN
# 143                       NaN                                   NaN
# 144                       NaN                                  2013
# 145                       NaN                                   NaN
# 146                       NaN                               2011/12
# 147                       NaN                            2008/ 2009
# 148                       NaN                                   NaN
# 149                       NaN                            2011/ 2012
# 150                       NaN                                  2008
# 151                       NaN                                   NaN
# 152                       NaN                                  2010
# 153                       NaN                            2008/ 2009
# 154                       NaN                                   NaN
# 155                       NaN                             2011/2012
# 156                       NaN                               2013/14
# 157                       NaN                                   NaN
# 158                       NaN  2008. Population and Housing Census.
# 159                       NaN                                   NaN
# 160                       NaN                             2004-2008
# 161                       NaN                            2009/ 2010
# 162                       NaN                                   NaN
# 163                       NaN                                   NaN
# 164                       NaN                                   NaN
# 165                       NaN                            2006/ 2007
# 166                       NaN                                   NaN
#
#     LatestIndustrialData LatestTradeData LatestWaterWithdrawalData
# 0                 2010.0          2013.0                    1999.0
# 1                 2010.0          2013.0                    2000.0
# 2                 2010.0          2013.0                    2006.0
# 3                 2010.0          2013.0                    1979.0
# 4                 2010.0          2013.0                    2005.0
# 5                 2005.0          2013.0                    2005.0
# 6                 2008.0          2013.0                    2005.0
# 7                 2010.0          2013.0                    2009.0
# 8                 2011.0          2013.0                    1975.0
# 9                 2011.0          2013.0                    2000.0
# 10                2010.0          2013.0                    2007.0
# 11                   NaN             NaN                       NaN
# 12                2010.0          2013.0                    2008.0
# 13                2010.0          2013.0                    2002.0
# 14                2010.0          2013.0                    2005.0
# 15                2011.0          2013.0                    1986.0
# 16                2010.0          2013.0                    2007.0
# 17                2010.0          2013.0                    2007.0
# 18                2010.0          2013.0                    2007.0
# 19                2010.0          2013.0                    2001.0
# 20                2010.0          2013.0                    2002.0
# 21                2010.0          2013.0                    2007.0
# 22                2010.0          2011.0                    2005.0
# 23                2010.0          2013.0                    2004.0
# 24                2010.0          2013.0                    2000.0
# 25                2006.0             NaN                    2005.0
# 26                2010.0          2013.0                    2008.0
# 27                2011.0          2013.0                    2002.0
# 28                2009.0          2013.0                    2002.0
# 29                   NaN          2013.0                       NaN
# ..                   ...             ...                       ...
# 137                  NaN          2009.0                    2000.0
# 138                  NaN          2013.0                    2002.0
# 139               2010.0          2013.0                    2002.0
# 140               2010.0          2012.0                    2002.0
# 141                  NaN          1995.0                    2005.0
# 142                  NaN          2012.0                    2006.0
# 143               2011.0          2003.0                    2004.0
# 144                  NaN          2000.0                    2006.0
# 145               2009.0          2013.0                    2002.0
# 146                  NaN          2013.0                    2001.0
# 147                  NaN          1997.0                    2000.0
# 148                  NaN          2009.0                    1999.0
# 149               2008.0          2013.0                    2006.0
# 150                  NaN          2013.0                    2000.0
# 151                  NaN          2005.0                    2000.0
# 152                  NaN          2013.0                    2005.0
# 153                  NaN          2013.0                    2002.0
# 154               2008.0          2002.0                    2005.0
# 155                  NaN          2013.0                    2002.0
# 156                  NaN          2013.0                    2000.0
# 157                  NaN          2008.0                    2001.0
# 158                  NaN             NaN                    2000.0
# 159               2004.0          2013.0                    2000.0
# 160               2002.0          2013.0                    2005.0
# 161                  NaN          2013.0                    2001.0
# 162               2006.0          2013.0                    2000.0
# 163                  NaN          2011.0                    2005.0
# 164               2010.0          2012.0                    2000.0
# 165               2010.0          2013.0                    2005.0
# 166                  NaN          2012.0                    2011.0
#
# [167 rows x 33 columns]

# %%
gdpregion = gdpfinal.groupby(['Region']).mean()

# %%
gdpregion
# Out:
#                             gdp_per_capita  LatestIndustrialData  \
# Region
# East Asia & Pacific           11515.043478           2009.000000
# Europe & Central Asia         25510.111111           2009.918919
# Latin America & Caribbean      9283.068966           2007.076923
# Middle East & North Africa    17910.937500           2009.642857
# North America                 49823.000000           2009.500000
# South Asia                     2751.875000           2008.500000
# Sub-Saharan Africa             2311.720930           2007.937500
#
#                             LatestTradeData  LatestWaterWithdrawalData
# Region
# East Asia & Pacific             2012.363636                2001.933333
# Europe & Central Asia           2012.380952                2005.886364
# Latin America & Caribbean       2012.000000                2005.607143
# Middle East & North Africa      2012.200000                2002.625000
# North America                   2013.000000                1995.500000
# South Asia                      2012.000000                2006.625000
# Sub-Saharan Africa              2010.825000                2002.697674

# %%
gdppivot = gdpfinal.pivot_table(index=['Region'], margins=True, aggfunc=np.mean)

# %%
gdppivot
# Out:
#                             LatestIndustrialData  LatestTradeData  \
# Region
# East Asia & Pacific                  2009.000000      2012.363636
# Europe & Central Asia                2009.918919      2012.380952
# Latin America & Caribbean            2007.076923      2012.000000
# Middle East & North Africa           2009.642857      2012.200000
# North America                        2009.500000      2013.000000
# South Asia                           2008.500000      2012.000000
# Sub-Saharan Africa                   2007.937500      2010.825000
# All                                          NaN              NaN
#
#                             LatestWaterWithdrawalData  gdp_per_capita
# Region
# East Asia & Pacific                       2001.933333    11515.043478
# Europe & Central Asia                     2005.886364    25510.111111
# Latin America & Caribbean                 2005.607143     9283.068966
# Middle East & North Africa                2002.625000    17910.937500
# North America                             1995.500000    49823.000000
# South Asia                                2006.625000     2751.875000
# Sub-Saharan Africa                        2002.697674     2311.720930
# All                                               NaN             NaN

# %%
gdppivot.drop(['LatestIndustrialData', 'LatestTradeData', 'LatestWaterWithdrawalData'], axis=1, inplace=True)

# %%
gdppivot
# Out:
#                             gdp_per_capita
# Region
# East Asia & Pacific           11515.043478
# Europe & Central Asia         25510.111111
# Latin America & Caribbean      9283.068966
# Middle East & North Africa    17910.937500
# North America                 49823.000000
# South Asia                     2751.875000
# Sub-Saharan Africa             2311.720930
# All                                    NaN
